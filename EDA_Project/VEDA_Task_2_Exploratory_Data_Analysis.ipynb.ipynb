# %%
# ==========================================
# VEDA TECHNOLOGY - TASK 2
# EXPLORATORY DATA ANALYSIS (EDA)
# ==========================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
sns.set_theme(style="whitegrid")

# Load dataset
df = pd.read_csv('/content/SampleSuperstore.csv')

print("Libraries imported successfully!")
print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

display(df.head())
# Out:
# Libraries imported successfully!
# Dataset loaded successfully!
# Rows: 9994
# Columns: 13
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
# ...

# %%
# ==========================================
# DATASET OVERVIEW
# ==========================================

print("Dataset Shape:")
print(df.shape)

print("\nColumn Names:")
print(df.columns.tolist())

print("\nData Types:")
display(df.dtypes)

print("\nFirst 5 Rows:")
display(df.head())

print("\nLast 5 Rows:")
display(df.tail())
# Out:
# Dataset Shape:
# (9994, 13)
#
# Column Names:
# ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit']
#
# Data Types:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object
# First 5 Rows:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...

# %%
# ==========================================
# DATA CLEANING
# ==========================================

# Clean column names
df.columns = df.columns.str.strip()

# Missing values
print("Missing Values:")
display(df.isnull().sum())

# Duplicate rows
print("\nDuplicate Rows:", df.duplicated().sum())

# Remove duplicates
df = df.drop_duplicates()

print("\nDataset Shape After Cleaning:", df.shape)

print("\nData Cleaning Completed Successfully!")
# Out:
# Missing Values:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64
# Duplicate Rows: 17
#
# Dataset Shape After Cleaning: (9977, 13)
#
# Data Cleaning Completed Successfully!

# %%
# ==========================================
# SUMMARY STATISTICS
# ==========================================

print("Numerical Summary Statistics:")
display(df.describe())

print("\nCategorical Summary Statistics:")
display(df.describe(include='object').T)
# Out:
# Numerical Summary Statistics:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600
# Categorical Summary Statistics:
#              count unique              top  freq
# Ship Mode     9977      4   Standard Class  5955
# Segment       9977      3         Consumer  5183
# Country       9977      1    United States  9977
# City          9977    531    New York City   914
# ...

# %%
# ==========================================
# KEY BUSINESS METRICS
# ==========================================

total_sales = df['Sales'].sum()
total_profit = df['Profit'].sum()
total_quantity = df['Quantity'].sum()
average_sales = df['Sales'].mean()
average_profit = df['Profit'].mean()
average_discount = df['Discount'].mean()

print("========== KEY BUSINESS METRICS ==========")

print(f"Total Sales      : ${total_sales:,.2f}")
print(f"Total Profit     : ${total_profit:,.2f}")
print(f"Total Quantity   : {total_quantity:,.0f}")
print(f"Average Sales    : ${average_sales:,.2f}")
print(f"Average Profit   : ${average_profit:,.2f}")
print(f"Average Discount : {average_discount:.2%}")
# Out:
# ========== KEY BUSINESS METRICS ==========
# Total Sales      : $2,296,195.59
# Total Profit     : $286,241.42
# Total Quantity   : 37,820
# Average Sales    : $230.15
# Average Profit   : $28.69
# Average Discount : 15.63%

# %%
# ==========================================
# VISUALIZATION 1
# SALES BY CATEGORY
# ==========================================

category_sales = (
    df.groupby('Category')['Sales']
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(9, 5))
category_sales.plot(kind='bar')

plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print("Observation:")
print(
    f"The {category_sales.idxmax()} category has the highest "
    f"total sales of ${category_sales.max():,.2f}."
)
# Out:
# Observation:
# The Technology category has the highest total sales of $836,154.03.

# %%
# ==========================================
# VISUALIZATION 2
# PROFIT BY CATEGORY
# ==========================================

category_profit = (
    df.groupby('Category')['Profit']
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(9, 5))
category_profit.plot(kind='bar')

plt.title('Total Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print("Observation:")
print(
    f"The {category_profit.idxmax()} category has the highest "
    f"total profit of ${category_profit.max():,.2f}."
)
# Out:
# Observation:
# The Technology category has the highest total profit of $145,454.95.

# %%
# ==========================================
# VISUALIZATION 3
# SALES BY REGION
# ==========================================

region_sales = (
    df.groupby('Region')['Sales']
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(9, 5))
region_sales.plot(kind='bar')

plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print("Observation:")
print(
    f"The {region_sales.idxmax()} region has the highest "
    f"total sales of ${region_sales.max():,.2f}."
)
# Out:
# Observation:
# The West region has the highest total sales of $725,255.64.

# %%
# ==========================================
# VISUALIZATION 4
# SALES BY SUB-CATEGORY
# ==========================================

subcategory_sales = (
    df.groupby('Sub-Category')['Sales']
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(12, 6))
subcategory_sales.plot(kind='bar')

plt.title('Total Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

print("Observation:")
print(
    f"The {subcategory_sales.idxmax()} sub-category has the highest "
    f"sales of ${subcategory_sales.max():,.2f}."
)
# Out:
# Observation:
# The Phones sub-category has the highest sales of $330,007.05.

# %%
# ==========================================
# VISUALIZATION 5
# PROFIT DISTRIBUTION
# ==========================================

plt.figure(figsize=(10, 5))

sns.histplot(
    df['Profit'],
    bins=40,
    kde=True
)

plt.title('Distribution of Profit')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

print("Observation:")
print(
    "The distribution shows how profit values are spread across "
    "the dataset. Negative profit values represent transactions "
    "that resulted in losses."
)
# Out:
# Observation:
# The distribution shows how profit values are spread across the dataset. Negative profit values represent transactions that resulted in losses.

# %%
# ==========================================
# VISUALIZATION 6
# SALES VS PROFIT
# ==========================================

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Sales',
    y='Profit',
    hue='Category',
    alpha=0.6
)

plt.title('Sales vs Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.tight_layout()
plt.show()

print("Observation:")
print(
    "The scatter plot shows the relationship between sales and "
    "profit. Higher sales do not always result in higher profit."
)
# Out:
# Observation:
# The scatter plot shows the relationship between sales and profit. Higher sales do not always result in higher profit.

# %%
# ==========================================
# VISUALIZATION 7
# CORRELATION HEATMAP
# ==========================================

numeric_columns = [
    'Sales',
    'Quantity',
    'Discount',
    'Profit'
]

correlation = df[numeric_columns].corr()

plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    linewidths=0.5
)

plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

print("Observation:")
print(
    "The heatmap shows the strength and direction of relationships "
    "between Sales, Quantity, Discount and Profit."
)
# Out:
# Observation:
# The heatmap shows the strength and direction of relationships between Sales, Quantity, Discount and Profit.

# %%
# ==========================================
# TOP 10 SUB-CATEGORIES BY SALES
# ==========================================

top_subcategories = (
    df.groupby('Sub-Category')['Sales']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(10, 6))

top_subcategories.sort_values().plot(kind='barh')

plt.title('Top 10 Sub-Categories by Sales')
plt.xlabel('Sales')
plt.ylabel('Sub-Category')
plt.tight_layout()
plt.show()

print("Top 10 Sub-Categories by Sales:")
display(top_subcategories)
# Out:
# Top 10 Sub-Categories by Sales:
# Sub-Category
# Phones         330007.0540
# Chairs         327777.7610
# Storage        223843.6080
# Tables         206965.5320
# Binders        203409.1690
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Name: Sales, dtype: float64

# %%
# ==========================================
# TOP 3 INSIGHTS
# ==========================================

top_sales_category = category_sales.idxmax()
top_sales_category_value = category_sales.max()

top_sales_region = region_sales.idxmax()
top_sales_region_value = region_sales.max()

top_profit_category = category_profit.idxmax()
top_profit_category_value = category_profit.max()

print("==========================================")
print("              TOP 3 INSIGHTS")
print("==========================================")

print(
    f"\n1. {top_sales_category} is the highest-sales category, "
    f"generating ${top_sales_category_value:,.2f} in total sales."
)

print(
    f"\n2. {top_sales_region} is the highest-sales region, "
    f"generating ${top_sales_region_value:,.2f} in total sales."
)

print(
    f"\n3. {top_profit_category} generates the highest total profit, "
    f"with ${top_profit_category_value:,.2f}."
)
# Out:
# ...
#               TOP 3 INSIGHTS
# ...
#
# 1. Technology is the highest-sales category, generating $836,154.03 in total sales.
#
# 2. West is the highest-sales region, generating $725,255.64 in total sales.
#
# 3. Technology generates the highest total profit, with $145,454.95.

# %%
# ==========================================
# FINAL CONCLUSION
# ==========================================

print("""
==========================================
             EDA CONCLUSION
==========================================

The Exploratory Data Analysis provided an overview of the
Superstore dataset and identified important patterns in sales,
profit, quantity, discount, categories, sub-categories and regions.

The analysis included data cleaning, descriptive statistics,
key business metrics, category analysis, regional analysis,
sub-category analysis, profit distribution and correlation analysis.

The visualizations helped identify differences in sales and
profitability across categories, sub-categories and regions.
The Sales vs Profit analysis also showed that higher sales
do not always result in higher profit.

Overall, the EDA provides useful insights that can support
further business analysis and data-driven decision making.
""")
# Out:
# ...
#              EDA CONCLUSION
# ...
#
# The Exploratory Data Analysis provided an overview of the
# Superstore dataset and identified important patterns in sales,
# profit, quantity, discount, categories, sub-categories and regions.
#
# The analysis included data cleaning, descriptive statistics,
# key business metrics, category analysis, regional analysis,
# sub-category analysis, profit distribution and correlation analysis.
#
# The visualizations helped identify differences in sales and
# profitability across categories, sub-categories and regions.
# The Sales vs Profit analysis also showed that higher sales
# do not always result in higher profit.
#
# Overall, the EDA provides useful insights that can support
# further business analysis and data-driven decision making.
